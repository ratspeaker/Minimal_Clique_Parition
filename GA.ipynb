# %%
def loadGraph(filename):
    with open(str(filename), "r") as graph_instance:
        chromatic_num = int(graph_instance.readline())
        V, E = list(map(int, graph_instance.readline().split(" ")))
        graph = [[] for _ in range(V)]
        for line in graph_instance:
            if line.startswith('e'):
                line = line.split(" ")
                del line[0]
                edge = list(map(int, line))
                if (edge[1]-1) not in graph[edge[0]-1]:
                    graph[edge[0] - 1].append(edge[1] - 1)
                    graph[edge[1] - 1].append(edge[0] - 1)
    return chromatic_num, graph

# %%
def printSolution(color):
    print("Solution: ", end = " ")
    for i in range(len(color)):
        print(str(color[i]), end=" ")
        
    print()

# %%
import random
import numpy as np

# %%
class Individual:
    
    def __init__(self, graph):
        self.graph = graph
        self.V = len(graph)
        self.code = []
        self.getCode()
        self.fitness = self.calcFitness()
        
    def __str__(self):
        return str(self.code)
        
    def __lt__(self, other):
        return self.fitness < other.fitness
    
    def isFeasible(self):
        for i in range(len(self.graph)):
            for neigh in self.graph[i]:
                if(self.code[i]==self.code[neigh]):
                    return False
            
        return True
    
    def randomChangeOperator(self):
        position = random.randrange(len(self.graph))
        old_color = self.code[position]
      
        new_color = random.randrange(1, len(self.graph)+1)
        
        self.code[position] = new_color
        if self.isFeasible():
            return position, old_color
        
        self.code[position] = old_color
        return -1, old_color
    
    def getCode(self):
        for i in range(self.V):
            self.code.append(random.randrange(1, self.V+1))
        
    def getAvailableColors(self, i):
        neighbors = [index for index in self.graph[i]]
        used_colors = [self.code[neighbor] for neighbor in neighbors]
        available_colors = [c for c in range(1, self.V+1) if c not in used_colors]
        return available_colors
    
    def repair(self):
        for i in range(self.V):
            neighbors = [index for index in self.graph[i]]
            used_colors = [self.code[neighbor] for neighbor in neighbors]
            if(self.code[i] in used_colors):  
                available_colors = [c for c in range(1, self.V+1) if c not in used_colors]
                self.code[i] = random.choice(available_colors)
        
    def calcFitness(self):
        penalty = 0
        for i in range(self.V):
            for j in self.graph[i]:
                if self.code[i] == self.code[j]:
                    penalty += 1
        return penalty + len(set(self.code))

# %%
def selection(population):
    TOURNAMENT_SIZE = 5
    min_fitness = float('inf')
    index = -1
    
    for i in range(TOURNAMENT_SIZE):
        candidate = random.randrange(len(population))
        if population[candidate].fitness < min_fitness:
            min_fitness = population[candidate].fitness
            index = candidate
    return index

# %%
def crossover(parent1, parent2, child1, child2):
    position = random.randrange(1, parent1.V-1)
    child1.code[:position] = parent1.code[:position]
    child2.code[:position] = parent2.code[:position]
    
    child1.code[position:] = parent2.code[position:]
    child2.code[position:] = parent1.code[position:]

# %%
def mutation(individual):
    MUTATION_PROB = 0.8
    p = random.random()
    if p < MUTATION_PROB:
        i = random.randrange(individual.V)
        old_color = individual.code[i]
        individual.code[i] = random.choice(individual.getAvailableColors(i))
        
        if individual.code[i] == old_color:
            individual.code[i] = random.randrange(1, individual.V)
    
    return individual

# %%
 def simulatedAnnealing(individual, chromatic_num, max_iters):
    for i in range(1, max_iters+1):
        if len(set(individual.code)) == chromatic_num:
            break
        
        position, old_color = individual.randomChangeOperator()
      
        if position < 0:
            continue
        
        new_value = individual.calcFitness()
        
        if new_value < individual.fitness:
            individual.fitness = new_value
        else:
            p = 1.0 / i ** 0.5
            q = random.uniform(0, 1)
            if p > q:
                individual.fitness = new_value
            else:
                individual.code[position] = old_color

# %%
POPULATION_SIZE = 50
ELITISIM_SIZE = 4

# %%
def GeneticAlgorithm(graph, chromatic_num, NUM_GENERATIONS):
    population = [Individual(graph) for _ in range(POPULATION_SIZE)]
    newPopulation = [Individual(graph) for _ in range(POPULATION_SIZE)]

    
    for i in range(NUM_GENERATIONS):        
        population.sort()
        newPopulation[:ELITISIM_SIZE] = population[:ELITISIM_SIZE]
    
        for j in range(ELITISIM_SIZE, POPULATION_SIZE, 2):
            parent1Index = selection(population)
            parent2Index = selection(population)
        
            crossover(population[parent1Index], population[parent2Index], newPopulation[j], newPopulation[j+1])
        
            mutation(newPopulation[j])
            mutation(newPopulation[j+1])
        
            newPopulation[j].fitness = newPopulation[j].calcFitness()
            newPopulation[j+1].fitness = newPopulation[j+1].calcFitness()
        simulatedAnnealing(min(newPopulation), chromatic_num, 10)
        population=newPopulation
    
        bestIndividual = min(population)
        bestValue = len(set(bestIndividual.code))
    
        if(bestValue == chromatic_num):
            break
    
    population.sort()

    bestIndividual = min(population)
    num_of_colors = len(set(bestIndividual.code))
 
    return num_of_colors, bestIndividual.code, i+1

# %%
graph_list = ['brute.txt', 'myciel3.col', 'myciel4.col', 'myciel5.col', 'myciel6.col', 'david.col', 'huck.col', 'jean.col']
import time
from termcolor import colored

for graph_file in graph_list:
            print()
            print(colored(graph_file, color="red"))
            for max_generations in [100, 1000, 10000]:
                graph = []
                chromatic_num, graph = loadGraph(graph_file)
                
                print(f'---------------------Max generations: {max_generations}---------------------')
                start = time.time()
                num_of_colors, color, num_of_iters = GeneticAlgorithm(graph, chromatic_num, max_generations)
                end = time.time()
                exec_time = end - start
                
                print('time: ', exec_time)
                printSolution(color)
                print(f'Chromatic number: {chromatic_num}, Found chromatic number: {num_of_colors}')
                print(f'Number of iters: {num_of_iters}')
# Out:
# brute.txt
# ---------------------Max generations: 100---------------------
# time:  0.0016734600067138672
# Solution:  5 3 1 2 1
# Chromatic number: 4, Found chromatic number: 4
# Number of iters: 1
# ---------------------Max generations: 1000---------------------
# time:  0.00235748291015625
# Solution:  2 1 5 3 5
# Chromatic number: 4, Found chromatic number: 4
# Number of iters: 1
# ---------------------Max generations: 10000---------------------
# time:  0.003928422927856445
# Solution:  3 4 1 2 1
# Chromatic number: 4, Found chromatic number: 4
# Number of iters: 1
#
# myciel3.col
# ---------------------Max generations: 100---------------------
# time:  0.010028600692749023
# Solution:  5 7 10 10 7 3 3 10 3 7 5
# Chromatic number: 4, Found chromatic number: 4
# Number of iters: 7
# ---------------------Max generations: 1000---------------------
# time:  0.00815129280090332
# Solution:  5 2 10 2 9 9 9 5 2 5 10
# Chromatic number: 4, Found chromatic number: 4
# Number of iters: 7
# ---------------------Max generations: 10000---------------------
# time:  0.003927469253540039
# Solution:  3 8 3 2 9 9 2 2 8 8 3
# Chromatic number: 4, Found chromatic number: 4
# Number of iters: 2
#
# myciel4.col
# ---------------------Max generations: 100---------------------
# time:  0.18117880821228027
# Solution:  19 21 19 10 20 20 10 22 22 22 19 20 2 2 10 20 2 22 22 21 2 21 19
# Chromatic number: 5, Found chromatic number: 6
# Number of iters: 100
# ---------------------Max generations: 1000---------------------
# time:  0.7133986949920654
# Solution:  7 8 23 8 7 23 18 18 23 7 8 17 8 23 18 17 23 18 17 17 17 8 7
# Chromatic number: 5, Found chromatic number: 5
# Number of iters: 341
# ---------------------Max generations: 10000---------------------
# time:  0.4967830181121826
# Solution:  20 12 20 6 12 21 3 20 21 12 6 20 6 21 3 3 3 21 21 21 3 6 12
# Chromatic number: 5, Found chromatic number: 5
# Number of iters: 237
#
# myciel5.col
# ---------------------Max generations: 100---------------------
# time:  0.5007617473602295
# Solution:  15 1 31 1 15 14 3 31 24 3 1 8 1 39 31 14 24 8 37 22 14 39 3 15 22 24 36 3 8 44 24 22 3 15 37 22 11 31 37 24 22 8 44 37 8 11 39
# Chromatic number: 6, Found chromatic number: 13
# Number of iters: 100
# ---------------------Max generations: 1000---------------------
# time:  5.236872673034668
# Solution:  19 33 37 6 44 18 6 19 37 19 44 34 34 34 6 33 18 18 34 6 33 33 37 44 2 37 17 2 17 2 2 2 17 44 2 2 17 17 34 34 34 17 6 2 44 19 33
# Chromatic number: 6, Found chromatic number: 9
# Number of iters: 1000
# ---------------------Max generations: 10000---------------------
# time:  53.64356994628906
# Solution:  47 33 42 28 47 47 33 28 28 47 42 42 21 25 20 47 25 21 25 21 21 25 16 16 21 20 20 47 47 20 20 21 33 16 21 20 21 33 25 21 28 25 33 47 20 28 42
# Chromatic number: 6, Found chromatic number: 8
# Number of iters: 10000
#
# myciel6.col
# ---------------------Max generations: 100---------------------
# time:  1.6656837463378906
# Solution:  82 93 1 75 22 23 50 1 1 68 41 41 75 40 95 40 76 72 10 68 47 53 50 78 13 38 26 78 47 67 81 81 72 22 34 94 75 93 82 68 38 34 93 34 47 35 53 10 35 95 26 54 76 95 23 76 54 82 10 68 82 34 95 94 95 67 2 2 93 71 81 54 13 2 93 10 71 38 75 67 2 47 22 41 54 34 72 34 23 95 54 93 26 23 40
# Chromatic number: 7, Found chromatic number: 28
# Number of iters: 100
# ---------------------Max generations: 1000---------------------
# time:  14.71063756942749
# Solution:  30 3 30 54 35 4 4 41 86 65 3 8 40 41 39 39 35 8 8 50 73 21 54 1 73 41 1 40 30 65 1 86 35 3 65 21 39 40 40 50 41 30 1 5 3 25 54 35 63 86 63 4 5 86 8 73 25 9 21 35 41 63 65 4 4 50 50 40 8 86 41 21 86 5 63 4 63 50 65 86 21 73 35 86 39 3 9 5 21 63 63 73 4 54 30
# Chromatic number: 7, Found chromatic number: 19
# Number of iters: 1000
# ---------------------Max generations: 10000---------------------
# time:  153.91614651679993
# Solution:  21 70 11 36 21 89 79 89 47 47 21 94 94 94 79 21 11 47 79 89 70 70 76 21 47 89 76 19 19 36 19 36 19 19 19 70 53 36 19 94 36 79 89 94 21 19 11 7 76 20 36 7 53 76 36 63 63 76 53 70 53 63 20 79 47 79 94 79 70 63 7 63 36 19 76 63 53 63 53 63 36 89 94 53 20 94 53 47 94 89 70 53 20 7 21
# Chromatic number: 7, Found chromatic number: 14
# Number of iters: 10000
#
# david.col
# ---------------------Max generations: 100---------------------
# time:  0.8584160804748535
# Solution:  26 49 74 5 58 5 83 44 36 82 27 38 36 58 26 64 63 63 53 36 40 3 44 27 40 27 38 63 38 3 5 44 30 74 81 59 83 31 36 64 59 5 64 64 64 15 36 17 15 59 36 36 83 58 80 30 44 3 53 17 80 17 63 28 83 59 26 64 30 53 27 5 27 27 49 83 53 28 81 15 74 28 7 15 40 63 28
# Chromatic number: 11, Found chromatic number: 25
# Number of iters: 100
# ---------------------Max generations: 1000---------------------
# time:  8.548650026321411
# Solution:  52 18 31 86 36 36 39 36 75 65 87 29 87 18 86 47 58 58 31 65 73 14 75 73 14 29 60 53 62 75 62 39 53 87 20 18 86 36 47 20 58 86 47 36 52 62 58 36 75 87 14 47 53 47 65 39 62 60 36 30 29 65 62 65 62 14 31 20 62 73 73 14 36 20 14 52 36 39 20 65 36 73 30 75 62 52 29
# Chromatic number: 11, Found chromatic number: 19
# Number of iters: 1000
# ---------------------Max generations: 10000---------------------
# time:  88.69425702095032
# Solution:  34 84 69 1 84 82 29 63 51 14 77 17 50 84 29 34 30 77 14 14 6 63 29 17 51 6 77 69 82 1 6 34 77 77 6 1 84 1 30 29 69 29 1 14 29 63 14 82 69 63 17 63 6 69 69 34 77 51 82 29 17 14 30 63 69 82 1 51 84 17 1 34 69 29 34 63 84 51 17 51 34 34 50 34 63 51 17
# Chromatic number: 11, Found chromatic number: 14
# Number of iters: 10000
#
# huck.col
# ---------------------Max generations: 100---------------------
# time:  0.6900792121887207
# Solution:  61 28 4 34 4 4 18 52 21 39 39 58 34 61 55 18 52 26 23 5 23 16 50 50 52 52 16 36 36 34 39 55 45 58 59 67 21 50 26 73 26 58 23 34 67 73 18 58 5 28 34 55 16 28 42 5 55 36 56 59 28 36 23 45 34 34 52 28 36 50 58 58 39 73
# Chromatic number: 11, Found chromatic number: 22
# Number of iters: 100
# ---------------------Max generations: 1000---------------------
# time:  6.408750295639038
# Solution:  51 29 9 23 29 51 48 48 29 13 9 56 16 69 42 69 56 9 13 2 42 13 6 48 2 51 51 16 49 51 34 48 2 9 49 23 9 6 16 13 2 29 16 5 42 56 69 51 6 5 23 49 34 9 4 48 34 23 69 29 42 42 69 13 48 2 48 9 16 56 16 2 6 13
# Chromatic number: 11, Found chromatic number: 16
# Number of iters: 1000
# ---------------------Max generations: 10000---------------------
# time:  69.00167083740234
# Solution:  69 74 74 52 62 67 74 69 39 62 28 74 23 65 16 28 16 28 74 69 39 74 23 69 15 28 16 74 39 69 74 31 16 62 62 62 65 15 28 67 67 23 39 23 65 39 28 39 31 52 62 67 3 67 65 15 3 65 3 23 62 15 67 15 67 69 62 28 16 69 62 52 31 15
# Chromatic number: 11, Found chromatic number: 13
# Number of iters: 10000
#
# jean.col
# ---------------------Max generations: 100---------------------
# time:  0.8950808048248291
# Solution:  57 56 56 2 19 63 6 48 23 63 31 51 51 48 19 52 73 31 8 33 15 51 33 31 36 63 42 24 52 51 62 8 2 13 36 57 15 15 36 48 62 19 73 42 19 11 56 33 48 42 42 48 73 13 62 15 9 11 57 42 73 52 24 52 23 33 48 56 13 73 36 36 33 2 23 11 62 56 11 56
# Chromatic number: 10, Found chromatic number: 22
# Number of iters: 100
# ---------------------Max generations: 1000---------------------
# time:  6.796993255615234
# Solution:  21 55 46 21 55 44 25 55 31 9 25 44 23 72 21 55 77 5 32 3 55 32 5 53 55 77 53 21 32 72 9 77 44 77 26 31 25 5 46 77 44 32 9 32 23 9 26 46 77 53 21 23 72 77 5 72 72 31 46 23 77 46 3 5 55 46 5 55 72 9 53 3 26 44 31 32 3 31 23 46
# Chromatic number: 10, Found chromatic number: 15
# Number of iters: 1000
# ---------------------Max generations: 10000---------------------
# time:  63.68626546859741
# Solution:  76 40 76 58 55 17 72 37 30 76 40 40 34 71 76 69 30 76 55 69 40 71 7 69 37 7 71 71 72 7 76 58 7 17 40 7 34 40 58 34 55 17 17 58 69 58 37 30 76 37 58 17 55 34 37 76 72 76 37 69 69 69 17 58 69 71 17 69 30 37 58 7 69 72 58 37 55 37 34 69
# Chromatic number: 10, Found chromatic number: 12
# Number of iters: 10000
