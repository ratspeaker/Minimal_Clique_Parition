# %%
def loadGraph(filename):
    with open(str(filename), "r") as graph_instance:
        chromatic_num = int(graph_instance.readline())
        V, E = list(map(int, graph_instance.readline().split(" ")))
        graph = [[] for _ in range(V)]
        for line in graph_instance:
            if line.startswith('e'):
                line = line.split(" ")
                del line[0]
                edge = list(map(int, line))
                if (edge[1]-1) not in graph[edge[0]-1]:
                    graph[edge[0] - 1].append(edge[1] - 1)
                    graph[edge[1] - 1].append(edge[0] - 1)
    return chromatic_num, graph

# %%
def printSolution(color):
    print("Solution: ", end = " ")
    for i in range(len(color)):
        print(str(color[i]), end=" ")
        
    print()

# %%
def verticesDegrees(graph):
    degrees = []
    V = len(graph)
    
    for i in range(V):
        degrees.append(len(graph[i]))
        
    return degrees

# %%
import random
import math

# %%
def isFeasible(solution, graph):
    for i in range(len(graph)):
        for j in graph[i]:
            if(solution[i] == solution[j]):
                return False
    return True

# %%
def repair(solution, graph, m_degree):
    V = len(graph)
    
    for i in range(len(graph)):
        neighbors = [index for index in graph[i]]
        used_colors = [solution[neighbor] for neighbor in neighbors]
        if(solution[i] in used_colors):  
            available_colors = [c for c in range(1, V+1) if c not in used_colors]
            solution[i] = random.choice(available_colors)

# %%
def initialize(graph, m_degree):
    solution = []
    V = len(graph)
    
    for i in range(V):
        solution.append(random.randrange(1, V+1))
    
    if not isFeasible(solution, graph):
        repair(solution, graph, m_degree)
        
    return solution

# %%
def randomChangeOperator(solution, graph, m_degree):
    V = len(solution)
    position = random.randrange(V)
    
    old_color = solution[position]
    new_color = random.randrange(1, m_degree+1)
    
    solution[position] = new_color
    if isFeasible(solution, graph):
        m_degree = m_degree - 1
        return position, old_color
   
    repairVertexColor(solution, position, old_color)
    
    return -1, old_color

# %%
def repairVertexColor(solution, position, old_color):
    solution[position] = old_color

# %%
def calcSolutionValue(solution):
    return len(set(solution))

# %%
def simulatedAnnealing(graph, iters, chromatic_num, m_degree):
    solution = initialize(graph, m_degree)
    curr_value = calcSolutionValue(solution)
    best_value = curr_value 
    
    for i in range(1, iters):
        if curr_value == chromatic_num:
            break
        
        position, old_color = randomChangeOperator(solution, graph, m_degree)

        if position<0: 
            continue
        
        new_value = calcSolutionValue(solution)
        
        if new_value < curr_value:
            curr_value = new_value
            if new_value < best_value:
                best_value = new_value
        else:
            p = 1.0 / i ** 0.5
            q = random.uniform(0, 1)  
            if p > q:
                curr_value = new_value
            else:
                repairVertexColor(solution, position, old_color)
    
    return best_value, solution, i

# %%
graph = []
chromatic_num, graph = loadGraph("brute.txt")

m_degree = max(verticesDegrees(graph))
num_of_colors, color, num_of_iters = simulatedAnnealing(graph, 10000, chromatic_num, m_degree)
printSolution(color)

print(f'Chromatic number: {chromatic_num}, Found chromatic number: {num_of_colors}')
print(f'Number of iters: {num_of_iters}')
# Out:
# Solution:  5 3 2 1 2
# Chromatic number: 4, Found chromatic number: 4
# Number of iters: 7

# %%
graph_list = ['brute.txt', 'myciel3.col', 'myciel4.col', 'myciel5.col', 'myciel6.col', 'david.col', 'huck.col', 'jean.col']
import time
from termcolor import colored

for graph_file in graph_list:
            print()
            print(colored(graph_file, color="red"))
            for max_iters in [100, 1000, 10000, 100000]:
                graph = []
                chromatic_num, graph = loadGraph(graph_file)
                m_degree = max(verticesDegrees(graph))
                
                print(f'---------------------Max iters: {max_iters}---------------------')
                start = time.time()
                num_of_colors, color, num_of_iters = simulatedAnnealing(graph, max_iters, chromatic_num, m_degree)
                end = time.time()
                exec_time = end - start
                
                print('time: ', exec_time)
                printSolution(color)
                print(f'Chromatic number: {chromatic_num}, Found chromatic number: {num_of_colors}')
                print(f'Number of iters: {num_of_iters}')
# Out:
# brute.txt
# ---------------------Max iters: 100---------------------
# time:  3.5762786865234375e-05
# Solution:  2 4 5 1 5
# Chromatic number: 4, Found chromatic number: 4
# Number of iters: 1
# ---------------------Max iters: 1000---------------------
# time:  3.552436828613281e-05
# Solution:  3 5 2 4 2
# Chromatic number: 4, Found chromatic number: 4
# Number of iters: 4
# ---------------------Max iters: 10000---------------------
# time:  1.9311904907226562e-05
# Solution:  2 4 3 5 3
# Chromatic number: 4, Found chromatic number: 4
# Number of iters: 1
# ---------------------Max iters: 100000---------------------
# time:  5.53131103515625e-05
# Solution:  5 3 1 4 1
# Chromatic number: 4, Found chromatic number: 4
# Number of iters: 4
#
# myciel3.col
# ---------------------Max iters: 100---------------------
# time:  0.00066375732421875
# Solution:  3 4 2 2 4 5 4 2 5 5 3
# Chromatic number: 4, Found chromatic number: 4
# Number of iters: 88
# ---------------------Max iters: 1000---------------------
# time:  0.00037932395935058594
# Solution:  1 4 5 5 2 1 4 1 4 1 5
# Chromatic number: 4, Found chromatic number: 4
# Number of iters: 63
# ---------------------Max iters: 10000---------------------
# time:  0.00038051605224609375
# Solution:  1 2 4 5 1 4 2 4 2 2 5
# Chromatic number: 4, Found chromatic number: 4
# Number of iters: 58
# ---------------------Max iters: 100000---------------------
# time:  0.0006229877471923828
# Solution:  1 2 5 5 3 3 3 1 5 3 2
# Chromatic number: 4, Found chromatic number: 4
# Number of iters: 122
#
# myciel4.col
# ---------------------Max iters: 100---------------------
# time:  0.0011334419250488281
# Solution:  3 4 10 9 18 7 19 5 9 7 1 1 2 5 23 7 23 19 3 4 7 2 10
# Chromatic number: 5, Found chromatic number: 11
# Number of iters: 99
# ---------------------Max iters: 1000---------------------
# time:  0.01190042495727539
# Solution:  2 4 1 10 6 9 10 8 10 8 2 6 4 2 1 4 7 6 8 7 7 7 9
# Chromatic number: 5, Found chromatic number: 8
# Number of iters: 999
# ---------------------Max iters: 10000---------------------
# time:  0.08927154541015625
# Solution:  3 10 3 1 10 3 1 6 1 6 9 9 7 9 9 9 3 1 6 7 7 10 11
# Chromatic number: 5, Found chromatic number: 6
# Number of iters: 9999
# ---------------------Max iters: 100000---------------------
# time:  0.8738946914672852
# Solution:  9 10 2 2 4 3 11 3 5 3 4 3 10 9 10 4 9 10 3 2 3 4 5
# Chromatic number: 5, Found chromatic number: 6
# Number of iters: 99999
#
# myciel5.col
# ---------------------Max iters: 100---------------------
# time:  0.003992795944213867
# Solution:  6 15 8 21 17 40 22 10 2 37 15 14 31 11 1 40 32 33 21 5 6 13 18 13 7 21 13 6 14 3 4 44 44 19 19 37 1 22 31 30 35 11 14 4 14 3 42
# Chromatic number: 6, Found chromatic number: 26
# Number of iters: 99
# ---------------------Max iters: 1000---------------------
# time:  0.04025626182556152
# Solution:  22 4 30 14 11 3 3 7 17 20 15 16 9 22 18 2 11 20 23 16 9 16 10 8 1 14 17 3 3 20 7 8 4 18 15 18 30 4 9 20 18 22 4 9 4 1 10
# Chromatic number: 6, Found chromatic number: 15
# Number of iters: 999
# ---------------------Max iters: 10000---------------------
# time:  0.29364681243896484
# Solution:  9 1 9 17 11 5 13 21 5 5 1 10 8 16 21 13 11 8 16 16 8 14 1 3 3 14 16 10 3 11 5 2 6 6 15 2 2 2 11 2 5 15 14 8 2 2 17
# Chromatic number: 6, Found chromatic number: 12
# Number of iters: 9999
# ---------------------Max iters: 100000---------------------
# time:  2.4131507873535156
# Solution:  5 12 20 20 17 5 8 5 8 18 17 23 12 20 20 14 8 23 8 23 23 10 5 14 12 19 10 14 5 12 4 18 5 10 4 12 14 20 4 23 10 23 19 12 10 19 8
# Chromatic number: 6, Found chromatic number: 11
# Number of iters: 99999
#
# myciel6.col
# ---------------------Max iters: 100---------------------
# time:  0.006510734558105469
# Solution:  26 27 38 57 8 41 34 85 17 31 50 11 21 49 95 2 32 91 37 37 75 67 15 49 6 5 40 25 86 1 32 15 20 11 31 18 75 90 16 6 13 20 44 84 13 90 7 38 2 14 28 24 44 30 86 36 56 88 7 23 5 72 31 49 86 44 94 30 87 5 22 22 22 73 11 11 53 93 72 4 18 28 1 13 13 84 43 8 19 19 36 94 43 69 21
# Chromatic number: 7, Found chromatic number: 54
# Number of iters: 99
# ---------------------Max iters: 1000---------------------
# time:  0.0634007453918457
# Solution:  31 35 32 88 4 77 20 29 5 27 43 32 43 33 18 33 33 15 15 22 27 32 28 42 49 28 14 41 29 5 27 28 24 45 45 20 41 68 27 42 33 68 29 44 71 38 6 24 22 18 49 77 28 15 22 47 38 47 24 18 33 47 47 33 44 27 47 31 33 49 41 62 29 42 27 21 22 22 66 22 71 38 42 44 21 31 24 11 14 42 22 45 4 15 20
# Chromatic number: 7, Found chromatic number: 32
# Number of iters: 999
# ---------------------Max iters: 10000---------------------
# time:  0.6655590534210205
# Solution:  6 23 21 24 20 21 7 16 1 2 24 30 24 6 29 17 6 20 46 29 29 46 42 19 20 37 23 31 30 14 29 2 15 5 34 14 8 29 31 37 34 8 31 30 6 19 40 27 14 27 46 42 15 40 34 14 1 17 29 33 46 8 14 21 29 16 2 40 23 19 33 34 32 27 19 30 15 27 2 15 30 6 5 29 16 5 46 31 32 5 29 32 8 24 20
# Chromatic number: 7, Found chromatic number: 25
# Number of iters: 9999
# ---------------------Max iters: 100000---------------------
# time:  6.496704578399658
# Solution:  14 11 40 38 31 9 25 1 6 9 11 23 25 5 25 39 14 25 1 32 25 16 6 17 39 6 6 36 19 9 9 32 39 17 17 41 19 25 19 16 36 17 36 31 44 17 47 47 43 16 5 41 23 31 47 41 37 43 1 31 43 40 39 40 9 1 41 1 5 40 23 39 40 17 23 43 44 37 9 31 11 5 23 37 40 5 25 39 39 32 44 39 43 5 6
# Chromatic number: 7, Found chromatic number: 21
# Number of iters: 99999
#
# david.col
# ---------------------Max iters: 100---------------------
# time:  0.004064083099365234
# Solution:  85 61 40 8 33 25 23 60 79 5 48 3 49 75 67 67 33 3 60 59 12 78 9 8 16 31 31 3 67 19 40 38 70 19 24 17 24 70 55 13 10 2 17 52 87 6 11 35 86 38 40 82 41 36 35 63 36 82 36 30 23 7 14 11 36 78 52 85 55 59 18 41 63 49 73 73 9 86 87 20 8 29 22 35 16 60 56
# Chromatic number: 11, Found chromatic number: 49
# Number of iters: 99
# ---------------------Max iters: 1000---------------------
# time:  0.04005026817321777
# Solution:  46 52 25 18 6 81 40 87 13 62 62 56 44 59 69 20 20 24 56 57 74 72 57 81 69 1 23 46 72 87 72 69 26 81 1 47 26 46 23 25 25 8 59 55 69 44 24 62 8 52 62 2 18 22 46 53 53 72 5 22 22 21 2 66 6 72 59 12 41 72 55 81 55 23 2 56 66 21 44 13 69 52 9 57 1 66 66
# Chromatic number: 11, Found chromatic number: 32
# Number of iters: 999
# ---------------------Max iters: 10000---------------------
# time:  0.39646053314208984
# Solution:  63 32 67 71 44 9 15 79 71 67 82 66 44 20 38 9 4 20 36 32 31 36 54 67 19 81 62 13 82 79 19 30 45 54 79 22 67 20 31 75 66 31 81 75 63 26 77 31 4 19 46 44 79 36 3 67 79 31 36 15 71 4 45 54 75 22 38 30 22 45 45 44 62 75 26 44 66 15 66 36 82 46 25 26 26 81 9
# Chromatic number: 11, Found chromatic number: 25
# Number of iters: 9999
# ---------------------Max iters: 100000---------------------
# time:  4.510380029678345
# Solution:  56 68 31 46 14 76 76 33 74 74 5 56 45 33 54 14 31 82 39 76 67 74 46 33 14 76 67 30 54 3 16 16 36 5 63 82 68 63 69 82 56 30 31 30 35 63 45 54 30 13 63 54 56 35 31 39 69 33 39 56 67 14 16 31 82 3 69 67 46 76 29 56 29 30 14 56 67 31 74 35 13 16 78 56 68 14 82
# Chromatic number: 11, Found chromatic number: 22
# Number of iters: 99999
#
# huck.col
# ---------------------Max iters: 100---------------------
# time:  0.003195047378540039
# Solution:  23 54 69 42 28 23 57 8 11 8 42 13 11 26 26 43 14 59 48 17 16 37 53 16 2 19 28 53 6 12 30 14 11 18 6 15 47 61 59 5 21 11 10 51 47 5 8 69 69 72 12 12 17 43 46 30 1 44 65 61 19 20 57 35 35 1 2 18 13 16 18 33 17 2
# Chromatic number: 11, Found chromatic number: 39
# Number of iters: 99
# ---------------------Max iters: 1000---------------------
# time:  0.03183865547180176
# Solution:  34 9 20 25 40 27 38 31 52 41 44 32 25 23 32 10 41 43 20 34 8 35 25 41 51 43 52 25 69 23 44 34 51 9 52 8 32 18 32 38 23 40 38 51 52 43 12 25 10 6 18 29 27 32 21 38 6 29 20 29 34 38 10 38 29 69 40 64 32 31 31 51 34 35
# Chromatic number: 11, Found chromatic number: 25
# Number of iters: 999
# ---------------------Max iters: 10000---------------------
# time:  0.31560778617858887
# Solution:  50 47 34 25 48 14 50 39 2 48 40 7 22 50 7 25 25 24 11 30 53 40 40 25 31 21 6 3 3 53 40 7 40 21 11 24 47 7 47 47 48 6 2 34 39 40 34 50 37 11 40 25 21 25 39 7 50 3 24 21 37 37 7 2 21 24 24 2 47 11 34 14 37 11
# Chromatic number: 11, Found chromatic number: 18
# Number of iters: 9999
# ---------------------Max iters: 100000---------------------
# time:  3.127251148223877
# Solution:  13 35 48 46 43 15 3 48 11 43 52 37 48 13 35 15 52 15 37 26 11 26 4 48 4 33 26 11 25 35 37 35 15 2 48 43 33 2 43 35 11 13 25 4 33 16 33 22 16 3 33 43 26 46 51 13 22 16 47 48 22 25 22 35 13 2 52 33 3 43 48 52 2 13
# Chromatic number: 11, Found chromatic number: 15
# Number of iters: 99999
#
# jean.col
# ---------------------Max iters: 100---------------------
# time:  0.003113269805908203
# Solution:  15 14 51 75 35 10 77 38 23 63 79 36 43 77 26 23 1 23 22 22 56 23 36 64 23 19 11 22 15 59 43 33 79 8 75 4 61 10 15 32 49 29 75 29 31 6 11 40 35 70 6 15 32 15 16 43 14 15 4 34 19 14 77 64 21 21 24 79 38 59 4 34 64 16 65 49 60 31 44 35
# Chromatic number: 10, Found chromatic number: 38
# Number of iters: 99
# ---------------------Max iters: 1000---------------------
# time:  0.02998661994934082
# Solution:  14 7 20 25 28 69 21 7 20 11 58 21 35 26 5 11 54 53 23 17 14 35 6 2 6 23 32 4 53 3 9 22 4 11 22 11 10 17 9 8 35 35 21 28 8 28 26 8 28 17 28 25 25 2 58 11 17 7 21 69 19 35 7 26 35 35 54 6 28 28 9 19 3 15 23 32 28 26 10 9
# Chromatic number: 10, Found chromatic number: 27
# Number of iters: 999
# ---------------------Max iters: 10000---------------------
# time:  0.289212703704834
# Solution:  36 1 26 7 33 33 3 26 26 35 7 2 8 14 6 36 10 19 13 23 13 14 12 7 14 30 13 12 8 35 10 13 3 11 13 7 11 35 13 23 35 26 6 1 26 23 2 8 26 12 23 10 12 10 2 36 7 30 33 14 6 6 33 23 3 30 33 10 10 2 30 19 36 7 6 13 23 23 8 23
# Chromatic number: 10, Found chromatic number: 17
# Number of iters: 9999
# ---------------------Max iters: 100000---------------------
# time:  2.927515983581543
# Solution:  6 19 15 3 32 15 2 3 1 3 6 18 22 21 5 27 27 15 6 23 3 2 28 27 30 1 18 28 23 23 22 6 19 18 21 3 6 22 28 23 1 23 3 22 30 5 32 1 30 21 30 2 32 6 19 30 32 18 21 30 18 5 21 30 5 35 35 19 35 5 35 30 1 19 30 27 35 23 28 6
# Chromatic number: 10, Found chromatic number: 15
# Number of iters: 99999
